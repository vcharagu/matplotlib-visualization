# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("marketing raw data.csv")
df
# Out:
#            Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0     9/11/2020     Monday       707     5211       651.375000        No Promo
# 1    10/11/2020    Tuesday      1455    10386      1298.250000   Promotion Red
# 2    11/11/2020  Wednesday      1520    12475      1559.375000  Promotion Blue
# 3    12/11/2020   Thursday      1726    14414      1801.750000        No Promo
# 4    13/11/2020     Friday      2134    20916      2614.500000        No Promo
# ..          ...        ...       ...      ...              ...             ...
# 177    5/5/2021  Wednesday      1400    11196      1119.600000        No Promo
# 178    6/5/2021   Thursday      2244    18611      2067.888889   Promotion Red
# 179    7/5/2021     Friday      2023    14502      1450.200000        No Promo
# 180    8/5/2021   Saturday      1483     8975      1121.875000        No Promo
# 181    9/5/2021     Sunday      1303     6968       871.000000        No Promo
#
# [182 rows x 6 columns]

# %%
plt.plot(df["Visitors"])
plt.show()

# %%
plt.plot(df["Visitors"])
plt.xticks(range(0,len(df["Visitors"])),df['Date'])
plt.show()

# %%
a=df.tail(10).reset_index()
plt.plot(a["Visitors"])
plt.xticks(range(0,len(a["Visitors"])),a['Date'],rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.bar(range(0,len(a["Visitors"])),a['Visitors'],label="No of Vizs",linewidth=10,color="red")
plt.plot(a["Revenue"])
plt.xticks(range(0,len(a["Visitors"])),a['Date'],rotation=90)
plt.title("Revenue Per Day")
plt.legend(loc="upper center")
plt.xlabel("Dates")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.bar(range(0,len(a["Revenue"])),a['Revenue'],label="No of Vizs",linewidth=10,color="green")
plt.bar(range(0,len(a["Visitors"])),a['Marketing Spend'],label="Marketing Spend	",linewidth=10,color="purple")

plt.plot(a["Visitors"])
plt.xticks(range(0,len(a["Visitors"])),a['Date'],rotation=90)
plt.title("Revenue Per Day")
plt.legend(loc="upper center")
plt.xlabel("Dates")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
a[["Revenue","Marketing Spend"]].plot(kind="bar",color=["green","red"],figsize=(12,8))
a['Visitors'].plot(c="blue",linestyle="-.",secondary_y=True)
plt.xticks(range(0,len(a["Visitors"])),a['Date'],rotation=90)
plt.title("Revenue Per Day")
plt.legend(loc="upper center")
plt.xlabel("Dates")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['Visitors'],df['Marketing Spend'],c="red",marker="+",label="marketing")
plt.title("Visitors and Revenue Per Day")
plt.legend(loc="upper left")
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")

plt.show()

# %%
df.head()
# Out:
#          Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0   9/11/2020     Monday       707     5211          651.375        No Promo
# 1  10/11/2020    Tuesday      1455    10386         1298.250   Promotion Red
# 2  11/11/2020  Wednesday      1520    12475         1559.375  Promotion Blue
# 3  12/11/2020   Thursday      1726    14414         1801.750        No Promo
# 4  13/11/2020     Friday      2134    20916         2614.500        No Promo

# %%
groups=df[["Promo","Revenue","Marketing Spend"]].groupby("Promo")
groups
fig, ax=plt.subplots(figsize=(15,10))

for promo, group in groups:
  ax.scatter(group["Revenue"],group['Marketing Spend'],marker="x",label=promo)
ax.legend()
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")
plt.title("Relationship b2in marketing spend and Revenue by promo",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Relationship b2in marketing spend and Revenue by promo')
